# %% [markdown]
# ## 결측치 처리

# %% [markdown]
# SimpleImputer() 클래스 : NaN 값 표시된 모든 누락 된 값을 열의 평균으로 변환
#
# isna() : NaN여부 확인 API
#
# fillna() : NaN값을 다른 값으로 대체 하는 API

# %%
import numpy as np
import pandas as pd
import seaborn as sns
import matplotlib.pyplot as plt

# %%
kaggle2020 = pd.read_csv('kaggle_survey_2020_responses_rm.csv', low_memory = False)
question = kaggle2020.iloc[0, :].T
answer = kaggle2020.drop([0])

# %%
drop_result = kaggle2020.drop(["Q8", "Q11", "Q13", "Q22"], axis = 1, inplace = True)

# %% [markdown]
# ### isna()로 결손 데이터 여부 확인

# %%
kaggle2020.isna().head()
# Out:
#    Time from Start to Finish (seconds)     Q1     Q2     Q3     Q4     Q5  \
# 0                                False  False  False  False  False  False
# 1                                False  False  False  False  False  False
# 2                                False  False  False  False  False  False
# 3                                False  False  False  False  False  False
# 4                                False  False  False  False  False  False
#
#       Q6  Q7_Part_1  Q7_Part_2  Q7_Part_3  ...  Q17_Part_7  Q17_Part_8  \
# 0  False      False      False      False  ...       False       False
# 1  False      False      False      False  ...       False        True
# 2  False      False      False      False  ...       False        True
# 3  False       True       True       True  ...        True        True
# 4  False      False       True      False  ...        True        True
#
#    Q17_Part_9  Q17_Part_10  Q17_Part_11  Q17_OTHER    Q20    Q21    Q24    Q25
# ...

# %%
kaggle2020.isna().sum()
# Out:
# Time from Start to Finish (seconds)        0
# Q1                                         0
# Q2                                         0
# Q3                                         0
# Q4                                       467
#                                        ...
# Q17_OTHER                              19626
# Q20                                     8633
# Q21                                     8754
# Q24                                     9307
# Q25                                     9466
# Length: 65, dtype: int64

# %% [markdown]
# ### fillna()로 결손 데이터 대체

# %%
kaggle2020["Q4"] = kaggle2020["Q4"].fillna("00")
kaggle2020["Q5"] = kaggle2020["Q5"].fillna("00")
kaggle2020["Q6"] = kaggle2020["Q6"].fillna("00")
kaggle2020["Q15"] = kaggle2020["Q15"].fillna("00")
kaggle2020["Q20"] = kaggle2020["Q20"].fillna("00")
kaggle2020["Q21"] = kaggle2020["Q21"].fillna("00")
kaggle2020["Q24"] = kaggle2020["Q24"].fillna("00")
kaggle2020["Q25"] = kaggle2020["Q25"].fillna("00")

# %%
kaggle2020.columns
# Out:
# Index(['Time from Start to Finish (seconds)', 'Q1', 'Q2', 'Q3', 'Q4', 'Q5',
#        'Q6', 'Q7_Part_1', 'Q7_Part_2', 'Q7_Part_3', 'Q7_Part_4', 'Q7_Part_5',
#        'Q7_Part_6', 'Q7_Part_7', 'Q7_Part_8', 'Q7_Part_9', 'Q7_Part_10',
#        'Q7_Part_11', 'Q7_Part_12', 'Q7_OTHER', 'Q14_Part_1', 'Q14_Part_2',
#        'Q14_Part_3', 'Q14_Part_4', 'Q14_Part_5', 'Q14_Part_6', 'Q14_Part_7',
#        'Q14_Part_8', 'Q14_Part_9', 'Q14_Part_10', 'Q14_Part_11', 'Q14_OTHER',
#        'Q15', 'Q16_Part_1', 'Q16_Part_2', 'Q16_Part_3', 'Q16_Part_4',
#        'Q16_Part_5', 'Q16_Part_6', 'Q16_Part_7', 'Q16_Part_8', 'Q16_Part_9',
#        'Q16_Part_10', 'Q16_Part_11', 'Q16_Part_12', 'Q16_Part_13',
#        'Q16_Part_14', 'Q16_Part_15', 'Q16_OTHER', 'Q17_Part_1', 'Q17_Part_2',
#        'Q17_Part_3', 'Q17_Part_4', 'Q17_Part_5', 'Q17_Part_6', 'Q17_Part_7',
#        'Q17_Part_8', 'Q17_Part_9', 'Q17_Part_10', 'Q17_Part_11', 'Q17_OTHER',
#        'Q20', 'Q21', 'Q24', 'Q25'],
#       dtype='object')

# %%
kaggle2020.isna().sum()
# Out:
# Time from Start to Finish (seconds)        0
# Q1                                         0
# Q2                                         0
# Q3                                         0
# Q4                                         0
#                                        ...
# Q17_OTHER                              19626
# Q20                                        0
# Q21                                        0
# Q24                                        0
# Q25                                        0
# Length: 65, dtype: int64

# %%
kaggle2020_sort = kaggle2020.sort_values(by = "Q4")
kaggle2020_sort
# Out:
#       Time from Start to Finish (seconds)                           Q1  \
# 7375                                   36                        18-21
# 7339                                   53                        35-39
# 15003                                  42                        25-29
# 10869                                  60                        25-29
# 1604                                   55                        25-29
# ...                                   ...                          ...
# 5437                                 1151                        18-21
# 17019                                 388                        18-21
# 5452                                  119                        18-21
# 17069                                 587                        18-21
# 0                   Duration (in seconds)  What is your age (# years)?
#
#                                            Q2  \
# 7375                                      Man
# ...

# %% [markdown]
# ## NaN값을 모두 0으로 변환

# %%
kaggle2020.fillna("00")
# Out:
#       Time from Start to Finish (seconds)                           Q1  \
# 0                   Duration (in seconds)  What is your age (# years)?
# 1                                    1838                        35-39
# 2                                  289287                        30-34
# 3                                     860                        35-39
# 4                                     507                        30-34
# ...                                   ...                          ...
# 20032                                 126                        18-21
# 20033                                 566                        55-59
# 20034                                 238                        30-34
# 20035                                 625                        22-24
# 20036                                1031                        22-24
#
#                                            Q2  \
# 0      What is your gender? - Selected Choice
# ...

# %%
kaggle2020.isna().sum()
# Out:
# Time from Start to Finish (seconds)        0
# Q1                                         0
# Q2                                         0
# Q3                                         0
# Q4                                         0
#                                        ...
# Q17_OTHER                              19626
# Q20                                        0
# Q21                                        0
# Q24                                        0
# Q25                                        0
# Length: 65, dtype: int64

# %%
#Single choice questions
single = ['Q1','Q2','Q3','Q4','Q5','Q6','Q15', 'Q20', 'Q21', 'Q24','Q25']
#Multiple choice questions
multi = ['Q7', 'Q14', 'Q16', 'Q17','Q23']

# %%
kaggle2020_sort
# Out:
#       Time from Start to Finish (seconds)                           Q1  \
# 7375                                   36                        18-21
# 7339                                   53                        35-39
# 15003                                  42                        25-29
# 10869                                  60                        25-29
# 1604                                   55                        25-29
# ...                                   ...                          ...
# 5437                                 1151                        18-21
# 17019                                 388                        18-21
# 5452                                  119                        18-21
# 17069                                 587                        18-21
# 0                   Duration (in seconds)  What is your age (# years)?
#
#                                            Q2  \
# 7375                                      Man
# ...

# %%
answer_Q7 = answer.filter(regex="Q7")
answer_Q7
# Out:
#       Q7_Part_1 Q7_Part_2 Q7_Part_3 Q7_Part_4 Q7_Part_5 Q7_Part_6   Q7_Part_7  \
# 1        Python         R       SQL         C       NaN       NaN  Javascript
# 2        Python         R       SQL       NaN       NaN       NaN         NaN
# 3           NaN       NaN       NaN       NaN       NaN      Java  Javascript
# 4        Python       NaN       SQL       NaN       NaN       NaN         NaN
# 5        Python       NaN       NaN       NaN       NaN       NaN         NaN
# ...         ...       ...       ...       ...       ...       ...         ...
# 20032       NaN       NaN       NaN       NaN       NaN       NaN         NaN
# 20033    Python       NaN       NaN       NaN       NaN       NaN         NaN
# 20034    Python       NaN       NaN       NaN       NaN       NaN         NaN
# 20035    Python       NaN       SQL         C       NaN      Java  Javascript
# 20036    Python       NaN       NaN       NaN       NaN       NaN         NaN
#
# ...

# %%
kaggle2020.fillna(00)
# Out:
#       Time from Start to Finish (seconds)                           Q1  \
# 0                   Duration (in seconds)  What is your age (# years)?
# 1                                    1838                        35-39
# 2                                  289287                        30-34
# 3                                     860                        35-39
# 4                                     507                        30-34
# ...                                   ...                          ...
# 20032                                 126                        18-21
# 20033                                 566                        55-59
# 20034                                 238                        30-34
# 20035                                 625                        22-24
# 20036                                1031                        22-24
#
#                                            Q2  \
# 0      What is your gender? - Selected Choice
# ...

# %%
kaggle2020_matrix = kaggle2020(columns = question)
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# <ipython-input-16-1a42f1db8aed> in <module>
# ----> 1 kaggle2020_matrix = kaggle2020(columns = question)
#
# TypeError: 'DataFrame' object is not callable

# %%
question.info()
# Out:
# ---------------------------------------------------------------------------
# AttributeError                            Traceback (most recent call last)
# <ipython-input-18-d67a48c136f8> in <module>
# ----> 1 question.info()
#
# ~\Anaconda3\envs\multi\lib\site-packages\pandas\core\generic.py in __getattr__(self, name)
#    5463             if self._info_axis._can_hold_identifiers_and_holds_name(name):
#    5464                 return self[name]
# -> 5465             return object.__getattribute__(self, name)
#    5466
#    5467     def __setattr__(self, name: str, value) -> None:
#
# AttributeError: 'Series' object has no attribute 'info'

# %%
question_matrix = Time from Start to Finish (seconds)
