# %%
import pymysql.cursors
import pandas as pd
import numpy as np

# %%
from sklearn.impute import SimpleImputer

# %%
df = pd.read_csv('2021-편집.csv')

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 201 entries, 0 to 200
# Data columns (total 17 columns):
#  #   Column                     Non-Null Count  Dtype
# ---  ------                     --------------  -----
#  0   성별_LABEL                   200 non-null    object
#  1   출생년도(YYYY)                 200 non-null    float64
#  2   교육정도_LABEL                 200 non-null    object
#  3   계열_LABEL                   200 non-null    object
#  4   수학여부_LABEL                 200 non-null    object
#  5   주된 일 이외 다른 일(부업) 여부_LABEL  198 non-null    object
#  6   주된일(주업) 실제 취업시간            200 non-null    float64
#  7   총 실제 취업시간                  200 non-null    float64
#  8   실제 취업시간 구분                 200 non-null    float64
#  9   실제 취업시간 구분_LABEL           200 non-null    object
#  10  산업(10차)_LABEL              200 non-null    object
#  11  직업(7차)_LABEL               200 non-null    object
#  12  종사상지위_LABEL                200 non-null    object
# ...

# %%
df.head()
# Out:
#   성별_LABEL  출생년도(YYYY)           교육정도_LABEL     계열_LABEL 수학여부_LABEL  \
# 0       남자      1962.0        대학교(4년제 대학포함)  공학, 제조 및 건설         졸업
# 1       남자      1970.0  전문대(초급대,2ㆍ3년제 대학포함)  공학, 제조 및 건설         졸업
# 2       남자      1985.0        대학교(4년제 대학포함)  공학, 제조 및 건설         졸업
# 3       남자      1976.0  전문대(초급대,2ㆍ3년제 대학포함)  공학, 제조 및 건설         졸업
# 4       남자      1979.0        대학교(4년제 대학포함)  경영, 행정 및 법학         졸업
#
#   주된 일 이외 다른 일(부업) 여부_LABEL  주된일(주업) 실제 취업시간  총 실제 취업시간  실제 취업시간 구분  \
# 0                       없었음             36.0       36.0         3.0
# 1                       없었음             50.0       50.0         3.0
# 2                       없었음             52.0       52.0         3.0
# 3                       없었음             52.0       52.0         3.0
# 4                       없었음             50.0       50.0         3.0
#
#   실제 취업시간 구분_LABEL         산업(10차)_LABEL         직업(7차)_LABEL   종사상지위_LABEL  \
# ...

# %%
df.isnull().sum()
# Out:
# 성별_LABEL                     1
# 출생년도(YYYY)                   1
# 교육정도_LABEL                   1
# 계열_LABEL                     1
# 수학여부_LABEL                   1
# 주된 일 이외 다른 일(부업) 여부_LABEL    3
# 주된일(주업) 실제 취업시간              1
# 총 실제 취업시간                    1
# 실제 취업시간 구분                   1
# 실제 취업시간 구분_LABEL             1
# 산업(10차)_LABEL                1
# 직업(7차)_LABEL                 1
# 종사상지위_LABEL                  1
# 교육정도 컨버젼_LABEL               1
# 만나이                          1
# 승수(Weight)                   1
# 경제활동상태 구분_LABEL              1
# dtype: int64

# %%
df = df.drop('승수(Weight)', axis =1)

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 201 entries, 0 to 200
# Data columns (total 16 columns):
#  #   Column                     Non-Null Count  Dtype
# ---  ------                     --------------  -----
#  0   성별_LABEL                   200 non-null    object
#  1   출생년도(YYYY)                 200 non-null    float64
#  2   교육정도_LABEL                 200 non-null    object
#  3   계열_LABEL                   200 non-null    object
#  4   수학여부_LABEL                 200 non-null    object
#  5   주된 일 이외 다른 일(부업) 여부_LABEL  198 non-null    object
#  6   주된일(주업) 실제 취업시간            200 non-null    float64
#  7   총 실제 취업시간                  200 non-null    float64
#  8   실제 취업시간 구분                 200 non-null    float64
#  9   실제 취업시간 구분_LABEL           200 non-null    object
#  10  산업(10차)_LABEL              200 non-null    object
#  11  직업(7차)_LABEL               200 non-null    object
#  12  종사상지위_LABEL                200 non-null    object
# ...

# %%
df = df.drop('주된일(주업) 실제 취업시간', axis =1)

# %%
df = df.drop('총 실제 취업시간', axis =1)

# %%
df = df.drop('실제 취업시간 구분', axis =1)

# %%
df = df.drop('주된 일 이외 다른 일(부업) 여부_LABEL', axis =1)

# %%
df = df.drop('실제 취업시간 구분_LABEL', axis =1)

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 201 entries, 0 to 200
# Data columns (total 11 columns):
#  #   Column           Non-Null Count  Dtype
# ---  ------           --------------  -----
#  0   성별_LABEL         200 non-null    object
#  1   출생년도(YYYY)       200 non-null    float64
#  2   교육정도_LABEL       200 non-null    object
#  3   계열_LABEL         200 non-null    object
#  4   수학여부_LABEL       200 non-null    object
#  5   산업(10차)_LABEL    200 non-null    object
#  6   직업(7차)_LABEL     200 non-null    object
#  7   종사상지위_LABEL      200 non-null    object
#  8   교육정도 컨버젼_LABEL   200 non-null    object
#  9   만나이              200 non-null    float64
#  10  경제활동상태 구분_LABEL  200 non-null    object
# dtypes: float64(2), object(9)
# memory usage: 17.4+ KB

# %%
df.head()
# Out:
#   성별_LABEL  출생년도(YYYY)           교육정도_LABEL     계열_LABEL 수학여부_LABEL  \
# 0       남자      1962.0        대학교(4년제 대학포함)  공학, 제조 및 건설         졸업
# 1       남자      1970.0  전문대(초급대,2ㆍ3년제 대학포함)  공학, 제조 및 건설         졸업
# 2       남자      1985.0        대학교(4년제 대학포함)  공학, 제조 및 건설         졸업
# 3       남자      1976.0  전문대(초급대,2ㆍ3년제 대학포함)  공학, 제조 및 건설         졸업
# 4       남자      1979.0        대학교(4년제 대학포함)  경영, 행정 및 법학         졸업
#
#           산업(10차)_LABEL         직업(7차)_LABEL   종사상지위_LABEL 교육정도 컨버젼_LABEL  \
# 0  A 농업, 임업 및 어업(01~03)       6 농림 어업 숙련 종사자  고용원이 없는 자영업자             대졸
# 1          F 건설업(41~42)             3 사무 종사자         상용근로자            초대졸
# 2          C 제조업(10~34)       2 전문가 및 관련 종사자         상용근로자             대졸
# 3          C 제조업(10~34)  8 장치 기계 조작 및 조립 종사자         상용근로자            초대졸
# 4          C 제조업(10~34)             3 사무 종사자         상용근로자             대졸
#
#     만나이 경제활동상태 구분_LABEL
# 0  58.0             취업자
# 1  50.0             취업자
# 2  35.0             취업자
# ...

# %%
#y = df['산업(10차)_LABEL']

# %%
#X=df.drop('산업(10차)_LABEL',axis=1)

# %%
#X.columns

# %%
#data=X.values

# %%
#y=y.values

# %%
df.replace('',np.nan,inplace=True)

# %%
df.describe()
# Out:
#            동, 읍면부          성별   출생년도(YYYY)        교육정도          계열  \
# count  200.000000  200.000000   200.000000  200.000000  200.000000
# mean     1.105000    1.445000  1976.470000    4.870000   55.365000
# std      0.307323    0.498213    10.364178    0.659755   27.460923
# min      1.000000    1.000000  1946.000000    4.000000   10.000000
# 25%      1.000000    1.000000  1970.000000    4.000000   30.000000
# 50%      1.000000    1.000000  1977.000000    5.000000   60.000000
# 75%      1.000000    2.000000  1983.000000    5.000000   70.000000
# max      2.000000    2.000000  1998.000000    7.000000  100.000000
#
#              수학여부         졸업년도  주된 일 이외 다른 일(부업) 여부  주된일(주업) 실제 취업시간  \
# count  200.000000   200.000000           200.000000       200.000000
# mean     1.040000   704.095000             1.955000        40.835000
# std      0.398994   961.932073             0.251578        11.309611
# min      1.000000     0.000000             0.000000         0.000000
# ...

# %%
import pandas_profiling

# %%
df.profile_report()
# Out:
# ...
# Render HTML:   0%|          | 0/1 [00:00<?, ?it/s]
# <iframe width="100%" height="800px" srcdoc="&lt;!doctype html&gt;&lt;html lang=en&gt;&lt;head&gt;&lt;meta charset=utf-8&gt;&lt;meta name=viewport content=&quot;width=device-width, initial-scale=1, shrink-to-fit=no&quot;&gt;&lt;meta name=description content=&quot;Profile report generated with the `pandas-profiling` Python package&quot;&gt;&lt;meta name=author content=&quot;Simon Brugman and the open source community.&quot;&gt;&lt;meta name=generator content=&quot;Pandas Profiling v2.12.0&quot;&gt;&lt;meta name=url content=https://github.com/pandas-profiling/pandas-profiling&gt;&lt;meta name=date content=&quot;2021-07-08 05:38:55.940747&quot;&gt;&lt;title&gt;Pandas Profiling Report&lt;/title&gt;&lt;style&gt;
# /*!
#  * Bootstrap v3.3.7 (http://getbootstrap.com)
#  * Copyright 2011-2016 Twitter, Inc.
#  * Licensed under MIT (https://github.com/twbs/bootstrap/blob/master/LICENSE)
# ...

# %%
type(df)
# Out:
# pandas.core.frame.DataFrame

# %%
#import numpy as np
from sklearn.impute import SimpleImputer

# %%
data = df.values

# %%
y = df['직업(7차)_LABEL']

# %%
X = df.drop('직업(7차)_LABEL')
# Out:
# ---------------------------------------------------------------------------
# KeyError                                  Traceback (most recent call last)
# <ipython-input-18-64d1fa941f6c> in <module>
# ----> 1 X = df.drop('직업(7차)_LABEL')
#
# ~\Anaconda3\envs\multi\lib\site-packages\pandas\core\frame.py in drop(self, labels, axis, index, columns, level, inplace, errors)
#    4313             level=level,
#    4314             inplace=inplace,
# -> 4315             errors=errors,
#    4316         )
#    4317
#
# ~\Anaconda3\envs\multi\lib\site-packages\pandas\core\generic.py in drop(self, labels, axis, index, columns, level, inplace, errors)
#    4151         for axis, labels in axes.items():
#    4152             if labels is not None:
# -> 4153                 obj = obj._drop_axis(labels, axis, level=level, errors=errors)
#    4154
#    4155         if inplace:
#
# ~\Anaconda3\envs\multi\lib\site-packages\pandas\core\generic.py in _drop_axis(self, labels, axis, level, errors)
# ...

# %%
X.columns
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# <ipython-input-15-901c1061bf7c> in <module>
# ----> 1 X.columns
#
# NameError: name 'X' is not defined
